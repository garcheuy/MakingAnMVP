# %%
import requests as req
import pandas as pd

# %%
url = 'http://hoopshype.com/salaries/players/'

# %%
salaries_df = pd.read_html(url)
salaries_df = salaries_df[0]
salaries_df.head(10)
# Out:
#    Unnamed: 0             Player \n\t\t\t\t\t\t\t2017/18\t\t\t\t\t\t  \
# 0         1.0      Stephen Curry                         $34,682,550
# 1         2.0       LeBron James                         $33,285,709
# 2         3.0       Paul Millsap                         $30,769,231
# 3         4.0     Gordon Hayward                         $29,727,900
# 4         5.0      Blake Griffin                         $29,512,900
# 5         6.0         Kyle Lowry                         $28,703,704
# 6         7.0        Mike Conley                         $28,530,608
# 7         8.0       James Harden                         $28,299,399
# 8         8.0  Russell Westbrook                         $28,299,399
# 9        10.0      DeMar DeRozan                         $27,739,975
#
#   \n\t\t\t\t\t\t\t2018/19\t\t\t\t\t\t \n\t\t\t\t\t\t\t2019/20\t\t\t\t\t\t  \
# 0                         $37,457,154                         $40,231,758
# ...

# %%
salaries_df = salaries_df.iloc[:,1:3]
salaries_df
# Out:
#                    Player \n\t\t\t\t\t\t\t2017/18\t\t\t\t\t\t
# 0           Stephen Curry                         $34,682,550
# 1            LeBron James                         $33,285,709
# 2            Paul Millsap                         $30,769,231
# 3          Gordon Hayward                         $29,727,900
# 4           Blake Griffin                         $29,512,900
# 5              Kyle Lowry                         $28,703,704
# 6             Mike Conley                         $28,530,608
# 7            James Harden                         $28,299,399
# 8       Russell Westbrook                         $28,299,399
# 9           DeMar DeRozan                         $27,739,975
# 10             Al Horford                         $27,734,405
# 11        Carmelo Anthony                         $26,243,760
# 12         Damian Lillard                         $26,153,057
# 13           Jrue Holiday                         $25,686,667
# ...
