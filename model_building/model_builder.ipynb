# %%
import pandas as pd
import os

# %%
# NBA stats csv
nba_data = os.path.join('..', 'data', 'final_seasonstats_.csv')

# %%
# create dataframe with NBA stats
player_stats_df = pd.read_csv(nba_data)
print(len(player_stats_df))
player_stats_df.head()
# Out:
# 12338
#    Year            Player  GS    MP   PER  TRB%  AST%  STL%  BLK%  TOV%    WS  \
# 0  1990  Charles Barkley*  79  3085  27.1  16.7  15.6   2.4   1.0  13.9  17.3
# 1  1990   David Robinson*  81  3002  26.3  18.5   8.7   2.2   6.5  13.3  15.1
# 2  1990  Hakeem Olajuwon*  82  3124  24.1  19.5  12.1   2.6   7.0  14.6  11.2
# 3  1990      Karl Malone*  82  3122  27.2  17.1  13.2   1.9   1.0  13.0  15.9
# 4  1990    Magic Johnson*  79  2937  26.6  10.2  45.5   2.2   0.7  16.9  16.5
#
#      FG%    3P%    2P%    FTA    FT%   PTS      mvp
# 0  0.600  0.217  0.632  744.0  0.749  1989  Not MVP
# 1  0.531  0.000  0.532  837.0  0.732  1993  Not MVP
# 2  0.501  0.167  0.502  536.0  0.713  1995  Not MVP
# 3  0.562  0.372  0.567  913.0  0.762  2540  Not MVP
# 4  0.480  0.384  0.510  637.0  0.890  1765      MVP

# %%
# clean_player_stats_df = player_stats_df.dropna()
# print(len(clean_player_stats_df))
clean_player_stats_df.head(20)
# Out:
#     Year            Player  GS    MP   PER  TRB%  AST%  STL%  BLK%  TOV%  \
# 0   1990  Charles Barkley*  79  3085  27.1  16.7  15.6   2.4   1.0  13.9
# 1   1990   David Robinson*  81  3002  26.3  18.5   8.7   2.2   6.5  13.3
# 2   1990  Hakeem Olajuwon*  82  3124  24.1  19.5  12.1   2.6   7.0  14.6
# 3   1990      Karl Malone*  82  3122  27.2  17.1  13.2   1.9   1.0  13.0
# 4   1990    Magic Johnson*  79  2937  26.6  10.2  45.5   2.2   0.7  16.9
# 5   1990   Michael Jordan*  82  3197  31.2  10.4  28.6   3.5   1.1   9.8
# 6   1991  Charles Barkley*  67  2498  28.9  15.3  20.6   2.2   0.8  12.6
# 7   1991   David Robinson*  81  3095  27.4  19.0  10.9   2.0   6.2  13.7
# 8   1991  Hakeem Olajuwon*  50  2062  24.3  19.9  10.2   2.9   6.4  13.9
# 9   1991      Karl Malone*  82  3302  24.8  17.2  14.7   1.4   1.5  10.9
# 10  1991    Magic Johnson*  79  2933  25.1  10.9  49.3   1.8   0.3  20.4
# 11  1991   Michael Jordan*  82  3034  31.6   9.5  25.2   3.7   1.7   8.7
# ...

# %%
# define features and outcomes for logistic regression model
# features = clean_player_stats_df.drop('mvp', axis = 1)
# features = features.drop('Player', axis = 1)
# features = features.drop('Year', axis = 1)
features.head(20)
# Out:
#     GS    MP   PER  TRB%  AST%  STL%  BLK%  TOV%    WS    FG%    3P%    2P%  \
# 0   79  3085  27.1  16.7  15.6   2.4   1.0  13.9  17.3  0.600  0.217  0.632
# 1   81  3002  26.3  18.5   8.7   2.2   6.5  13.3  15.1  0.531  0.000  0.532
# 2   82  3124  24.1  19.5  12.1   2.6   7.0  14.6  11.2  0.501  0.167  0.502
# 3   82  3122  27.2  17.1  13.2   1.9   1.0  13.0  15.9  0.562  0.372  0.567
# 4   79  2937  26.6  10.2  45.5   2.2   0.7  16.9  16.5  0.480  0.384  0.510
# 5   82  3197  31.2  10.4  28.6   3.5   1.1   9.8  19.0  0.526  0.376  0.548
# 6   67  2498  28.9  15.3  20.6   2.2   0.8  12.6  13.4  0.570  0.284  0.614
# 7   81  3095  27.4  19.0  10.9   2.0   6.2  13.7  17.0  0.552  0.143  0.554
# 8   50  2062  24.3  19.9  10.2   2.9   6.4  13.9   8.6  0.508  0.000  0.510
# 9   82  3302  24.8  17.2  14.7   1.4   1.5  10.9  15.5  0.527  0.286  0.529
# 10  79  2933  25.1  10.9  49.3   1.8   0.3  20.4  15.4  0.477  0.320  0.532
# ...

# %%
outcomes = clean_player_stats_df['mvp']
print(features.shape, outcomes.shape)
# Out:
# (10213, 15) (10213,)

# %%
# Split data using train_test_split
from sklearn.model_selection import train_test_split

features_train, features_test, outcomes_train, outcomes_test = train_test_split(features, outcomes, random_state=0, stratify=outcomes)

# %%
# Create a logistic regression model
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# Fit the model to the data
classifier.fit(features_train, outcomes_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# Score against test data
classifier.score(features_test, outcomes_test)
# Out:
# 0.99686765857478465

# %%
# Make predictions using the X_test and y_test data
# Print at least 10 predictions vs their actual labels
predicted = classifier.predict(features_test)

print(f'Predictions: {predicted[:10]}')
print(f'Actuals: {outcomes_test[:10].tolist()}')
# Out:
# Predictions: ['Not MVP' 'Not MVP' 'Not MVP' 'Not MVP' 'Not MVP' 'Not MVP' 'Not MVP'
#  'Not MVP' 'Not MVP' 'Not MVP']
# Actuals: ['Not MVP', 'Not MVP', 'Not MVP', 'Not MVP', 'Not MVP', 'Not MVP', 'Not MVP', 'Not MVP', 'Not MVP', 'Not MVP']
